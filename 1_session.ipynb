# %% [markdown]
# # Variables

# %%
name ="Prabhat"
print(name)
# Out:
# Prabhat

# %%
a = 5
b = 6
print(5+6)
# Out:
# 11

# %%
type(name)
# Out:
# str

# %%
type(a+b)
# Out:
# int

# %% [markdown]
# ## The interprter of Python supports the dynamic typing

# %%
a = 5
print(a)
# Out:
# 5

# %%
# Dynamic binding
a = 5
print(a)
b = "Hello"
print(b)
# Out:
# 5
# Hello

# %%
# more ways to declare variables
a,b,c = 5,6,7
print(a,b,c)


a=b=c=5
print(a,b,c)
# Out:
# 5 6 7
# 5 5 5

# %% [markdown]
# # Keywords and Identifiers

# %% [markdown]
# ##### Difference between compilation and the Interpretation: The compilation converts the whole code into machine code at once and then executes it whereas the interpretation converts the code line by line into machine code and executes it line by line. hence the interprter of Python supports the dynamic typing
